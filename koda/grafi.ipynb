# %%
import matplotlib.pyplot as plt

#graf prikazuje kako se čas izvjanja spreminja glede na število k, gledamo kvadratne mreže
stevilo_k = 9
cas_k = [0.013472318649291992,
0.029506444931030273,
  0.03785262107849121,
  0.04043316841125488,
  0.0404057502746582,
  0.03966355323791504,
  0.0459712028503418,
  0.03946847915649414,
  0.007873868942260743]

cas_k_1= [0.06974401473999023,
  0.38941102027893065,
  0.5356775283813476,
  0.6694540977478027,
  0.8090893745422363,
  0.7630510330200195,
  0.7933205604553223,
  0.7857920169830322,
  0.834883737564087]

cas_k_2=[0.3511918544769287,
  3.804697561264038,
  5.74139142036438,
  7.110379457473755,
  7.451314783096313,
  8.160267639160157,
  8.776272678375244,
  9.76746654510498,
  9.610258769989013]

plt.plot(list(range(1,stevilo_k+1)), cas_k_2, label= "5x5")
plt.plot(list(range(1,stevilo_k+1)), cas_k_1, label= "4x4")
plt.plot(list(range(1,stevilo_k+1)), cas_k, label= "3x3")

plt.xlabel("Število k")
plt.ylabel("Čas izvajanja")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Čas izvajanja pri različnih kvadratnih mrežah')

plt.show()
#SKLEP: večje kot je število k, daljši je čas izvajanja

# %%
#graf prikazuje kako se čas izvjanja spreminja glede na odstranjevanje vozlišč
stevilo_k = 16
cas_a = [6.504718780517578,
  4.981656392415364,
  3.9737189610799155,
  2.7020649115244546,
  2.2296737829844155,
  1.8580498695373535,
  1.4150586128234863,
  0.7529439131418864,
  0.5770793755849203,
  0.25095899899800617,
  0.1535468896230062,
  0.0457759698232015,
  0.03904604911804199,
  0.01893603801727295,
  0.01611936092376709,
  0.012810945510864258]


cas_a_1= [7.487201690673828,
  6.041184902191162,
  5.035860141118367,
  3.598379373550415,
  3.1194588343302407,
  2.0125699043273926,
  1.1334784825642903,
  1.1940178871154785,
  0.420822540918986,
  0.44588104883829754,
  0.20993828773498535,
  0.09488860766092937,
  0.04657872517903646,
  0.06394426027933757,
  0.02182451883951823,
  0.007621447245279948]

cas_a_2 = [3.191605011622111,
  2.529470602671305,
  1.7827825546264648,
  1.312950849533081,
  0.9809106985727946,
  0.5926516056060791,
  0.5157786210378011,
  0.16061139106750488,
  0.037947654724121094,
  0.15410363674163818,
  0.03417325019836426,
  0.020245075225830078,
  None,
  0.016802549362182617,
  None,
  None]

plt.plot(list(range(1,stevilo_k+1)),cas_a_2, label = "k=2")
plt.plot(list(range(1,stevilo_k+1)), cas_a,label="k=5")
plt.plot(list(range(1,stevilo_k+1)),cas_a_1, label = "k=10")

plt.xlabel("Število odstranjenih vozlišč")
plt.ylabel("Čas izvajanja")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Odstranjevanje vozlišč pri mreži 5x5')

plt.show()
#SKLEP: več vozlišč kot odstranimo, krajši je čas

# %%
#graf prikazuje kako se čas izvjanja spreminja glede na odstranjevanje povezav
stevilo_k = 11
cas_a =[6.982829014460246,
  6.869829575220744,
  6.645777066548665,
  6.857503096262614,
  6.487318277359009,
  5.483149766921997,
  6.3019914627075195,
  6.373339653015137,
  5.202674547831218,
  3.9060733318328857,
  3.4323221842447915]


cas_a_1= [3.7485268910725913,
  3.525449514389038,
  2.990750233332316,
  3.4767260551452637,
  3.294132630030314,
  2.6013529300689697,
  2.910796801249186,
  3.1790095965067544,
  1.2931663990020752,
  2.825355418523153,
  3.121424535889038]


cas_a_2 = [8.279716571172079,
  8.406361977259317,
  8.444816748301188,
  8.199879884719849,
  8.466672420501709,
  8.38364044825236,
  6.317469835281372,
  8.603663682937622,
  8.959964672724405,
  5.848912000656128,
  5.242031574249268]

plt.plot(list(range(1,stevilo_k+1)),cas_a_2, label = "k=10")
plt.plot(list(range(1,stevilo_k+1)), cas_a,label="k=5")
plt.plot(list(range(1,stevilo_k+1)),cas_a_1, label = "k=2")

plt.xlabel("Število odstranjenih povezav")
plt.ylabel("Čas izvajanja")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Odstranjevanje povezav pri mreži 5x5')

plt.show()

# %%
#graf prikazuje kako se optimalna vrednost 2D mreže spreminja glede na 3D mrežo
stevilo_k = 10
cas_a = [6,4,3,2,2,2,2,2,2,1]
cas_a_1= [4.0, 3.0, 3.0, 2.0, 2.0, 2.0, 2.0, 1.0, 1.0, 1.0]

plt.plot(list(range(1,stevilo_k+1)),cas_a_1, label = "3D mreza 4x3x3")
plt.plot(list(range(1,stevilo_k+1)), cas_a,label="2D mreza 6x6")
plt.xlabel("število k")
plt.ylabel("Optimalna vrednost")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Primerjava 3D in 2D mreže')

plt.show()

# %%
#graf prikazuje kako se čas izvajanja 2D mreže spreminja glede na 3D mrežo
stevilo_k = 10
cas_a = [1.6993153095245361,
  29.09699773788452,
  46.4828679561615,
  48.2749240398407,
  55.68004059791565,
  61.543983936309814,
  65.75518798828125,
  66.11482667922974,
  68.91637325286865,
  70.79530596733093]
cas_a_1= [1.3744,24.2125,37.6758,49.3276,54.0472,62.1392,65.5273,66.7933,67.0000,73.5362]

plt.plot(list(range(1,stevilo_k+1)),cas_a, label = "3D mreza 4x3x3")
plt.plot(list(range(1,stevilo_k+1)), cas_a_1,label="2D mreza 6x6")
plt.xlabel("Število k")
plt.ylabel("Čas izvajanja")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Primerjava 3D in 2D mreže')

plt.show()

# %%
#graf prikazuje kako se optimalna vrednost drevesa z 25 vozlišči spreminja glede na mrežo z istim številom vozlišč
stevilo_k = 10
cas_a = [4.0, 3.0, 3.0, 2.0, 2.0, 2.0, 1.0, 1.0, 1.0, 1.0]
cas_a_1= [6.0, 5.0, 3.0, 3.0, 2.0, 2.0, 2.0, 2.0, 1.5, 1.0]

plt.plot(list(range(1,stevilo_k+1)), cas_a,label="5x5 mreza")
plt.plot(list(range(1,stevilo_k+1)),cas_a_1, label = "drevo z 10 vozlišči")

plt.xlabel("število k")
plt.ylabel("Optimalna vrednost")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Primerjava drevesa in kvadratne mreže')

plt.show()

# %%
#graf prikazuje kako se optimalna vrednost pravokotne mreže 3x17 oz. 5x10 spreminja glede na kvadratno mrežo 7x7 
stevilo_k = 10
cas_a = [6,5,4,3,3,2,2,2,2,2]
cas_a_1= [7,4,4,3,3,2,2,2,2,2]
cas_a_2=[9,5,4,3,3,2,2,2,2,2]

plt.plot(list(range(1,stevilo_k+1)),cas_a_2, label = "mreza 3x17")
plt.plot(list(range(1,stevilo_k+1)), cas_a_1,label="mreza 5x10")
plt.plot(list(range(1,stevilo_k+1)), cas_a,label="mreza 7x7")

plt.xlabel("število k")
plt.ylabel("Optimalna vrednost")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Primerjava pravokotne in kvadratne mreže')

plt.show()

# %%
#graf prikazuje kako se čas izvajanja pravokotne mreže 3x17 spreminja glede na kvadratno mrežo 7x7 
stevilo_k = 5
cas_a = [5.835,155, 268, 308, 362 ]
cas_a_1= [9.380363941192627, 228.9351544380188,366.8589463233948, 442.0993399620056,534.537225723266]
cas_a_2= [8.3,243,392.7,485.855,510.7]

plt.plot(list(range(1,stevilo_k+1)),cas_a_1, label = "mreza 5x10")
plt.plot(list(range(1,stevilo_k+1)), cas_a,label="mreza 7x7")
plt.plot(list(range(1,stevilo_k+1)),cas_a_2, label = "mreza 3x17")

plt.xlabel("število k")
plt.ylabel("Čas izvajanja")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Primerjava pravokotne in kvadratne mreže')

plt.show()
