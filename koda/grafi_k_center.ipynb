# %%
# %run k-center.ipynb
import numpy as np
import matplotlib.pyplot as plt
#PRI VSEH GRAFIH JE TREBA OS, KI PRIKAZUJE ČAS(SEKUNDE) PRIKAZATI NA BOLJ "DROBNO"

#graf prikazuje kako se čas izvjanja spreminja glede na število k 
stevilo_k = 5 
cas_k = cas_izvajanja_za_vec_ponovitev(5,5,3,2,stevilo_k,5)[1]
print("čas izvajanja je: " + str(cas_k))
plt.plot(list(range(1,stevilo_k+1)), cas_k)
plt.xlabel("Število k")
plt.ylabel("Čas izvajanja")

plt.show()
#SKLEP: večje kot je število k, daljši je čas izvajanja
# Out:
# čas izvajanja je: [0.19670376777648926, 1.4986090183258056, 2.3283442497253417, 2.9417778968811037, 3.3011605739593506]

# %%
#Graf prikazuje, kako se spreminja povprečna optimalna razdalja, ko povečujemo k
max_stevilo_centrov = 7 
povprecja = opt_vrednost_za_vec_ponovitev(5,5,3,2,max_stevilo_centrov,5)[1] #vzame  povprečja
print("Povprečja optimalne vrednosti R glede na k: " + str(povprecja))
plt.plot(list(range(1,max_stevilo_centrov+1)), povprecja)
plt.xlabel("Število k")
plt.ylabel("Povprečen R")

plt.show()

#SKLEP: več kot je centrov, manjša je razdalja
# Out:
# Povprečja optimalne vrednosti R glede na k: [4, 3, 2, 2, 2, 8/5, 1]

# %%
#graf prikazuje čas izvjanja glede na število izbrisanih vozlišč
stevilo_izbirsanih_vozlisc = 8
cas_vozlisca = cas_v_odvisnosti_od_spreminjanja_stevila_vozlisc(5,5,stevilo_izbirsanih_vozlisc-1,2,3,3)[1]
print("čas izvajanja glede na število izbrisanih vozlišč je: " + str(cas_vozlisca))
plt.plot(list(range(1,stevilo_izbirsanih_vozlisc+1)), cas_vozlisca)
plt.xlabel("število izbrisanih vozlišč")
plt.ylabel("čas izvajanja")

plt.show()
#SKLEP: več vozlišč kot izbrišemo, hitreje se algoritem izvede
# Out:
# čas izvajanja glede na število izbrisanih vozlišč je: [5.26, 4.01, 3.03, 2.14, 0.91, 1.15, 0.6, 0.32]

# %%
#NE DELA OKEJ!! - težave z None

#graf prikazuje kako se optimalna vrednost R spreminja glede na število izbrisanih vozlišč
izbrisana_vozlisca = 15
cas_izbrisana_vozlisca = R_v_odvisnosti_od_spreminjanje_stevila_vozlisc(5,5,izbrisana_vozlisca-1,2,3,3)[1]
print("Povprečja optimalne vrednosti R glede na število izbrisanih vozlišč: " + str(cas_izbrisana_vozlisca))
plt.plot(list(range(1,izbrisana_vozlisca+1)), cas_izbrisana_vozlisca)
plt.xlabel("Število izbrisanih vozlišč")
plt.ylabel("Povprečen R")

plt.show()
#SKLEP: //
# Out:
# Povprečja optimalne vrednosti R glede na število izbrisanih vozlišč: [3, 8/3, 3, 8/3, 8/3, 7/3, 10/3, 5/2, 2, 3, 3, None, None, None, None]

# %%
#X-OS NI OK! - > VELIKOST MREZE
#graf prikazuje kako se optimalna vrednost R spreminja glede na velikost mreže
m = 7 #dolocimo velikost mreze
n = 5
R_mreza = R_v_odvisnosti_od_velikosti_mreze(m,n,2,3,3,3)[1]
print("Povprečja optimalne vrednosti R glde na velikost mreze: " + str(R_mreza))
dolzina = len(R_mreza)
plt.plot(list(range(1,dolzina+1)), R_mreza)
plt.xlabel("????")
plt.ylabel("optimalna vrednost R")

plt.show()
#SKLEP: večja kot je mreža, daljša je razdalja do centra
# Out:
# Povprečja optimalne vrednosti R glde na velikost mreze: [2, 3, 3]

# %%
#X-OS NI OK! - > VELIKOST MREZE

#graf prikazuje kako se optimalna vrednost R spreminja glede na velikost kvadratne mreže
velikost = 5 #dolocimo velikost mreze
R_mreza_kvadratna = R_v_odvisnosti_od_velikosti_kvadratne_mreze(velikost,3,2,3,3)[1]
print("Povprečja optimalne vrednosti R glde na velikost kvadratne mreze: " + str(R_mreza_kvadratna))
dolzina_kvadratna = len(R_mreza_kvadratna)
plt.plot(list(range(1,dolzina_kvadratna+1)), R_mreza_kvadratna)
plt.xlabel("??")
plt.ylabel("optimalna vrednost R")

plt.show()
#SKLEP: večja kot je kvadratna mreža večja je oddaljenost od centra
# Out:
# Povprečja optimalne vrednosti R glde na velikost kvadratne mreze: [1, 2, 8/3]
